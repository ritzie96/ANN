# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.metrics import mean_squared_error

# %%
X_train =  pd.read_csv("bindigit_trn.csv",header=None).as_matrix()
y_train = pd.read_csv("targetdigit_trn.csv",header=None,names=["Label"]).as_matrix()

X_test = pd.read_csv("bindigit_tst.csv",header=None).as_matrix()
y_test = pd.read_csv("targetdigit_tst.csv",header=None,names=["Label"]).as_matrix()

# %%
plt.hist(y_train)
plt.title("Distribution of labels")
plt.show()

# %%
y_train.shape
# Out:
# (8000, 1)

# %%
#Helper class for plotting images
def plotImage(images,predictions):
    n = 10  # how many digits we will display
    plt.figure(figsize=(20, 4))
    for i in range(n):
        # display original
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(images[i].reshape(28, 28))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # display reconstruction
        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(predictions[i].reshape(28, 28))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# %%
def plotWeights(weights):
    n = weights.shape[0]  # how many digits we will display
    plt.figure(figsize=(20, 20))
    for i in range(n):
        # display weights
        ax = plt.subplot(10, 10, i + 1)
        plt.imshow(weights[i].reshape(28, 28))
        #plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# %%
from  keras.layers import Input, Dense
from keras.models import Model
# Out:
# Using TensorFlow backend.

# %%
# this is the size of our encoded representations
encoding_dim = 50  #hidden nodes in compression layer

# this is our input placeholder
input_img = Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(784, activation='sigmoid')(encoded)

# this model maps an input to its reconstruction
autoencoder50 = Model(input_img, decoded)

# this model maps an input to its encoded representation
encoder50 = Model(input_img, encoded)

# %%
# this is the size of our encoded representations
encoding_dim = 75  #hidden nodes in compression layer

# this is our input placeholder
input_img = Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(784, activation='sigmoid')(encoded)

# this model maps an input to its reconstruction
autoencoder75 = Model(input_img, decoded)

# %%
# this is the size of our encoded representations
encoding_dim = 100  #hidden nodes in compression layer

# this is our input placeholder
input_img = Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(784, activation='sigmoid')(encoded)

# this model maps an input to its reconstruction
autoencoder100 = Model(input_img, decoded)

# this model maps an input to its encoded representation
encoder100 = Model(input_img, encoded)

# %%
# this is the size of our encoded representations
encoding_dim = 150  #hidden nodes in compression layer

# this is our input placeholder
input_img = Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(784, activation='sigmoid')(encoded)

# this model maps an input to its reconstruction
autoencoder150 = Model(input_img, decoded)

# %%
'''
 #Separate encoder model#Separat 
# this model maps an input to its encoded representation
encoder = Model(input_img, encoded)
'''
# Out:
# '\n #Separate encoder model#Separat \n# this model maps an input to its encoded representation\nencoder = Model(input_img, encoded)\n'

# %%
'''

#Separate decoder model
# create a placeholder for an encoded (32-dimensional) input
encoded_input = Input(shape=(encoding_dim,))
# retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# create the decoder model
decoder = Model(encoded_input, decoder_layer(encoded_input))

'''
# Out:
# '\n\n#Separate decoder model\n# create a placeholder for an encoded (32-dimensional) input\nencoded_input = Input(shape=(encoding_dim,))\n# retrieve the last layer of the autoencoder model\ndecoder_layer = autoencoder.layers[-1]\n# create the decoder model\ndecoder = Model(encoded_input, decoder_layer(encoded_input))\n\n'

# %%
autoencoder50.compile(optimizer='adadelta', loss='mean_squared_error')
encoder50.compile(optimizer='adadelta', loss='mean_squared_error')
autoencoder75.compile(optimizer='adadelta', loss='mean_squared_error')
autoencoder100.compile(optimizer='adadelta', loss='mean_squared_error')
encoder100.compile(optimizer='adadelta', loss='mean_squared_error')
autoencoder150.compile(optimizer='adadelta', loss='mean_squared_error')

# %%
history50 = autoencoder50.fit(X_train, X_train,
                epochs=50,
                batch_size=64,
                shuffle=True,
                verbose=1,
                validation_data=(X_test, X_test))
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/50
# 8000/8000 [==============================] - 5s 563us/step - loss: 0.1767 - val_loss: 0.0984
# Epoch 2/50
# 8000/8000 [==============================] - 4s 446us/step - loss: 0.0926 - val_loss: 0.0897
# Epoch 3/50
# 8000/8000 [==============================] - 3s 400us/step - loss: 0.0890 - val_loss: 0.0878
# Epoch 4/50
# 8000/8000 [==============================] - 2s 256us/step - loss: 0.0873 - val_loss: 0.0862
# Epoch 5/50
# 8000/8000 [==============================] - 3s 326us/step - loss: 0.0857 - val_loss: 0.0844
# Epoch 6/50
# 8000/8000 [==============================] - 3s 322us/step - loss: 0.0837 - val_loss: 0.0822
# Epoch 7/50
# 8000/8000 [==============================] - 3s 337us/step - loss: 0.0813 - val_loss: 0.0796
# Epoch 8/50
# 8000/8000 [==============================] - 2s 281us/step - loss: 0.0787 - val_loss: 0.0769
# Epoch 9/50
# ...

# %%
history75 = autoencoder75.fit(X_train, X_train,
                epochs=50,
                batch_size=64,
                shuffle=True,
                verbose=1,
                validation_data=(X_test, X_test))
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/50
# 8000/8000 [==============================] - 4s 520us/step - loss: 0.1753 - val_loss: 0.0979
# Epoch 2/50
# 8000/8000 [==============================] - 3s 434us/step - loss: 0.0923 - val_loss: 0.0894
# Epoch 3/50
# 8000/8000 [==============================] - 3s 344us/step - loss: 0.0886 - val_loss: 0.0872
# Epoch 4/50
# 8000/8000 [==============================] - 2s 280us/step - loss: 0.0866 - val_loss: 0.0853
# Epoch 5/50
# 8000/8000 [==============================] - 2s 279us/step - loss: 0.0846 - val_loss: 0.0830
# Epoch 6/50
# 8000/8000 [==============================] - 2s 252us/step - loss: 0.0821 - val_loss: 0.0804
# Epoch 7/50
# 8000/8000 [==============================] - 2s 238us/step - loss: 0.0794 - val_loss: 0.0776
# Epoch 8/50
# 8000/8000 [==============================] - 2s 206us/step - loss: 0.0767 - val_loss: 0.0749
# Epoch 9/50
# ...

# %%
history100 = autoencoder100.fit(X_train, X_train,
                epochs=50,
                batch_size=64,
                shuffle=True,
                verbose=1,
                validation_data=(X_test, X_test))
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/50
# 8000/8000 [==============================] - 5s 601us/step - loss: 0.1711 - val_loss: 0.0971
# Epoch 2/50
# 8000/8000 [==============================] - 3s 385us/step - loss: 0.0921 - val_loss: 0.0893
# Epoch 3/50
# 8000/8000 [==============================] - 2s 265us/step - loss: 0.0884 - val_loss: 0.0871
# Epoch 4/50
# 8000/8000 [==============================] - 2s 245us/step - loss: 0.0864 - val_loss: 0.0850
# Epoch 5/50
# 8000/8000 [==============================] - 2s 259us/step - loss: 0.0843 - val_loss: 0.0827
# Epoch 6/50
# 8000/8000 [==============================] - 2s 242us/step - loss: 0.0817 - val_loss: 0.0799
# Epoch 7/50
# 8000/8000 [==============================] - 2s 244us/step - loss: 0.0788 - val_loss: 0.0768
# Epoch 8/50
# 8000/8000 [==============================] - 2s 226us/step - loss: 0.0758 - val_loss: 0.0739
# Epoch 9/50
# ...

# %%
history150 = autoencoder150.fit(X_train, X_train,
                epochs=50,
                batch_size=64,
                shuffle=True,
                verbose=1,
                validation_data=(X_test, X_test))
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/50
# 8000/8000 [==============================] - 5s 670us/step - loss: 0.1676 - val_loss: 0.0959
# Epoch 2/50
# 8000/8000 [==============================] - 3s 423us/step - loss: 0.0910 - val_loss: 0.0880
# Epoch 3/50
# 8000/8000 [==============================] - 3s 359us/step - loss: 0.0867 - val_loss: 0.0848
# Epoch 4/50
# 8000/8000 [==============================] - 3s 335us/step - loss: 0.0837 - val_loss: 0.0818
# Epoch 5/50
# 8000/8000 [==============================] - 2s 271us/step - loss: 0.0806 - val_loss: 0.0785
# Epoch 6/50
# 8000/8000 [==============================] - 2s 242us/step - loss: 0.0774 - val_loss: 0.0752
# Epoch 7/50
# 8000/8000 [==============================] - 2s 242us/step - loss: 0.0742 - val_loss: 0.0721
# Epoch 8/50
# 8000/8000 [==============================] - 2s 245us/step - loss: 0.0712 - val_loss: 0.0694
# Epoch 9/50
# ...

# %%
loss = history50.history['loss']
valLoss = history50.history['val_loss']
plt.plot(range(len(loss)),loss,color='red',label='Training error')
plt.plot(range(len(valLoss)),valLoss,color='blue',label='Testing error')
plt.title('Error vs epochs')
plt.legend()
plt.show()

# %%
loss = history75.history['loss']
valLoss = history75.history['val_loss']
plt.plot(range(len(loss)),loss,color='red',label='Training error')
plt.plot(range(len(valLoss)),valLoss,color='blue',label='Testing error')
plt.title('Error vs epochs')
plt.legend()
plt.show()

# %%
loss = history100.history['loss']
valLoss = history100.history['val_loss']
plt.plot(range(len(loss)),loss,color='red',label='Training error')
plt.plot(range(len(valLoss)),valLoss,color='blue',label='Testing error')
plt.title('Error vs epochs')
plt.legend()
plt.show()

# %%
loss = history150.history['loss']
valLoss = history150.history['val_loss']
plt.plot(range(len(loss)),loss,color='red',label='Training error')
plt.plot(range(len(valLoss)),valLoss,color='blue',label='Testing error')
plt.title('Error vs epochs')
plt.legend()
plt.show()

# %%
# encode and decode some digits
# note that we take them from the *test* set
#encoded_imgs = encoder.predict(X_test)
#decoded_imgs = decoder.predict(encoded_imgs)

pred50 = autoencoder50.predict(X_test)
pred75 = autoencoder75.predict(X_test)
pred100 = autoencoder100.predict(X_test)
pred150 = autoencoder150.predict(X_test)
#a50 = autoencoder.predict(X_test[:10,:])
#a150 = autoencoder.predict(X_test[:10,:])

# %%
plotImage(X_test[:10,:],pred50)

# %%
plotImage(X_test[:10,:],pred75)

# %%
plotImage(X_test[:10,:],pred100)

# %%
plotImage(X_test[:10,:],pred150)

# %%
#Calculate mean squared error
mse50 = mean_squared_error(X_test,pred50)
mse75 = mean_squared_error(X_test,pred75)
mse100 = mean_squared_error(X_test,pred100)
mse150 = mean_squared_error(X_test,pred150)
print(mse50)
print(mse75)
print(mse100)
print(mse150)
# Out:
# 0.04185816855
# 0.0394691665982
# 0.0386285031974
# 0.0353046338637

# %%
weights50 = autoencoder50.get_weights()[0].T
weights100 = autoencoder100.get_weights()[0].T

# %%
plotWeights(weights50)

# %%
plotWeights(weights100)
